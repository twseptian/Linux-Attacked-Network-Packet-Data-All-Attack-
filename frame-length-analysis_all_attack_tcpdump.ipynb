# %%
import pandas as pd
df=pd.read_table("frame.len")

# %%
df.head()
# Out:
#    frame.number  frame.len
# 0             1        590
# 1             2        590
# 2             3        590
# 3             4         60
# 4             5         42

# %%
df["frame.len"].describe()
# Out:
# count    3329833.000000
# mean         163.334237
# std          315.842112
# min           42.000000
# 25%           60.000000
# 50%           66.000000
# 75%           86.000000
# max         1514.000000
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
infodata = df["frame.len"].plot(style=".", alpha=0.2,figsize=(20,20),title="Frame Length All Attack TCPdump")
infodata.set_ylabel("bytes")
infodata.set_xlabel("frame number")

# %%
fig = infodata.get_figure()
fig.savefig("Frame Length All Attack Tcpdump.png")
